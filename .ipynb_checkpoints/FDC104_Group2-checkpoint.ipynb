# %% [markdown]
# # Group 2: Bike Sharing Demand Prediction

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ## 2. Data Description

# %% [markdown]
# #### Thông tin chi tiết về dữ liệu:
# Dữ liệu có 8760 quan sát vơi 14 trường:
# - Date : year-month-day
# - Rented Bike count - Count of bikes rented at each hour (output attribute)
# - Hour - Hour of he day
# - Temperature-Temperature in Celsius
# - Humidity - %
# - Windspeed - m/s
# - Visibility - 10m
# - Dew point temperature - Celsius
# - Solar radiation - MJ/m2
# - Rainfall - mm
# - Snowfall - cm
# - Seasons - Winter, Spring, Summer, Autumn
# - Holiday - Holiday/No holiday
# - Functional Day - NoFunc(Non Functional Hours), Fun(Functional hours)

# %%
path = 'https://github.com/trangmx/fdc104/raw/main/datasets/bike_sharing/Bike_sharing_data.csv'

# Thêm tham số encoding='latin1' để sửa lỗi Unicode
df = pd.read_csv(path, encoding='latin1')
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %% [markdown]
# ## 3. Data Processing

# %% [markdown]
# ## 4. EDA

# %% [markdown]
# ## 5. Model
